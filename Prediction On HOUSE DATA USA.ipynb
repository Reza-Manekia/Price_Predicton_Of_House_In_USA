# %% [markdown]
# # Price Predction of House Data USA
#
# ### Import the dataset and perform exploratory data analysis (EDA)

# %%
# Importing relevant Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:\DS_AI_POWER-BI\House Data USA.csv")

# %%
# Explore the dataset

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.401822e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.673622e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
# Drop unneccessary Columns from our dataset

# %%
columns_to_keep = ['sqft_living', 'bedrooms', 'bathrooms', 'view', 'yr_built', 'price']
df = df.drop(columns=df.columns.difference(columns_to_keep))
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  view  yr_built
# 0  221900.0         3       1.00         1180     0      1955
# 1  538000.0         3       2.25         2570     0      1951
# 2  180000.0         2       1.00          770     0      1933
# 3  604000.0         4       3.00         1960     0      1965
# 4  510000.0         3       2.00         1680     0      1987

# %%
# Visualize the target variable

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['price'], kde=True)
plt.title('Distribution of House Prices')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %%
# Explore feature relationships

# Scatter plot of sqft_living vs. price

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='sqft_living', y='price')
plt.title('Square Footage vs. Price')
plt.show()

# %%
# Correlation heatmap

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Handle categorical features

# Count plot of view

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='view')
plt.title('Count of View')
plt.xlabel('View')
plt.ylabel('Count')
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Plot 1 - Distribution of bedrooms
axs[0].hist(df['bedrooms'], bins=10, edgecolor='black', alpha=0.65)
axs[0].set_title('Distribution of Bedrooms')
axs[0].set_xlabel('Number of Bedrooms')
axs[0].set_ylabel('Count')

# Plot 2 - Distribution of bathrooms
axs[1].hist(df['bathrooms'], bins=10, edgecolor='black', alpha=0.65)
axs[1].set_title('Distribution of Bathrooms')
axs[1].set_xlabel('Number of Bathrooms')
axs[1].set_ylabel('Count')


plt.tight_layout()


plt.show()

# %%
# Additional analysis
# Time series analysis

# %%
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)
df['price'].plot(figsize=(12, 6))
plt.title('House Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ## Splitting Of data set into train and test

# %%
from sklearn.model_selection import train_test_split

dependants = ['sqft_living', 'bedrooms', 'bathrooms', 'view', 'yr_built']

X_train, X_test, y_train, y_test = train_test_split(df[dependants], df['price'], test_size=0.2, random_state=42)

print("Training set shape:", X_train.shape, y_train.shape)
print("Testing set shape:", X_test.shape, y_test.shape)
# Out:
# Training set shape: (17290, 5) (17290,)
# Testing set shape: (4323, 5) (4323,)

# %% [markdown]
# ## Model Training (Linear Regression)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Calculating Mean_Absolute_error

# %%
from sklearn.metrics import mean_absolute_error

y_pred = model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)

print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 163020.36792413326

# %%
# Prediction of price of house when
# 2000 sq-ft 
# 3 bedrooms
# 2 bathrooms
# 0 view
# 1990 year_built

# %%
new_house_features = [2000, 3, 2, 0, 1990]

predicted_price = model.predict([new_house_features])

print("Predicted price:", round(predicted_price[0]))
# Out:
# Predicted price: 460017
# D:\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
